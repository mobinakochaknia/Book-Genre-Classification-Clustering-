# %% [markdown]
# # Word Embeddings
#
# Welcome to this complete, self-contained solution notebook on **text preprocessing** and **word embeddings**.
#
# In this assignment, we will work with book metadata such as titles, authors, descriptions, genres, and places. Our goal is to transform this raw text into meaningful numerical representations that can capture relationships between words.
#
# ---
#
# ## 🎯 Assignment Goal
#
# The main objective is to train, test, visualize, and compare different word embedding models.
#
# We will implement and explore three approaches:
#
# ### 1. Word2Vec from Scratch
# We will build a simple **Skip-Gram Word2Vec model** using negative sampling.
# This helps us understand how word embeddings are learned internally.
#
# ### 2. FastText with Gensim
# We will train a FastText model using the `gensim` library.
# FastText improves on Word2Vec by learning from subword information, which helps with rare or unseen words.
#
# ### 3. FastText with the Native `fasttext` Package
# We will also use the official `fasttext` package to train embeddings and compare its behavior with the Gensim implementation.
#
# ---
#
# ## 🧠 What You Will Learn
#
# By the end of this notebook, you will be able to:
#
# - clean and normalize raw book metadata,
# - convert text into a training corpus,
# - build a vocabulary from tokenized text,
# - generate Skip-Gram training pairs,
# - train word embeddings from scratch,
# - train FastText embeddings using two different libraries,
# - test semantic relationships using simple analogy examples,
# - visualize learned word vectors in two dimensions,
# - compare the strengths and limitations of Word2Vec and FastText.
#
# ---
#
# ## 🧩 Final Outcome
#
# At the end of the notebook, we will have multiple trained embedding models and a clearer understanding of how different embedding techniques represent words, authors, genres, and places in a shared vector space.

# %% [markdown]
# ## 1. Environment Setup
#
# The notebook contains all assignment code directly in notebook cells.
#
# Some libraries may already be installed in your environment. If a package is missing, run the optional installation cell below.

# %%
# Optional installation cell.
# Change RUN_INSTALLS to True only if your environment is missing packages.

RUN_INSTALLS = True

if RUN_INSTALLS:
    import sys
    import subprocess

    packages = [
        "pandas",
        "numpy",
        "matplotlib",
        "nltk",
        "gensim",
        "tqdm",
        "fasttext",
    ]

    subprocess.check_call([
        sys.executable,
        "-m",
        "pip",
        "install",
        "-q",
        *packages,
    ])

    print("Packages installed.")
else:
    print("Skipping installation. Set RUN_INSTALLS = True if packages are missing.")
# Out:
# Packages installed.

# %%
import math
import random
import re
import tempfile
import pickle
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# Some libraries still have non-deterministic behavior when using multiple workers,
# but fixing these seeds makes the scratch model and sampling steps more stable.
RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)


try:
    from tqdm.auto import tqdm
except Exception:
    def tqdm(iterable, **kwargs):
        return iterable

print("Core libraries loaded.")
# Out:
# Core libraries loaded.

# %% [markdown]
# ## 2. Dataset
#
# For a fully standalone run, this notebook includes a small built-in book metadata dataset.
#
# The dataset has the same kind of columns expected in this assignment:
#
# - `title`
# - `author`
# - `description`
# - `genres`
# - `places`
#
# A larger CSV can also be used by setting `USE_EXTERNAL_CSV = True`.

# %%
CSV_PATH = Path("top_3000_rated_books.csv")


if CSV_PATH.exists():
    books_df = pd.read_csv(CSV_PATH)
    data_source = f"Loaded external dataset from {CSV_PATH}"

print(data_source)
print(f"Number of rows: {len(books_df)}")
books_df.head()
# Out:
# Loaded external dataset from top_3000_rated_books.csv
# Number of rows: 3000
#    Unnamed: 0  bookId                                     title  \
# 0        4249    4255  Harry Potter and the Philosopher's Stone
# 1           2       3     Harry Potter and the Sorcerer's Stone
# 2       12110   12024                                  Twilight
# 3        2656    2661                     To Kill a Mockingbird
# 4        2655    2660                     To Kill a Mockingbird
#
#                        author                 series  \
# 0                J.K. Rowling        Harry Potter #1
# 1  J.K. Rowling,Mary GrandPré        Harry Potter #1
# 2             Stephenie Meyer   The Twilight Saga #1
# 3                  Harper Lee  To Kill a Mockingbird
# 4                  Harper Lee  To Kill a Mockingbird
#
#                                          description  \
# 0  When a letter arrives for unhappy but ordinary...
# 1  Harry Potter's life is miserable. His parents ...
# 2  About three things I was absolutely positive.,...
# 3  Lawyer Atticus Finch defends the real mockingb...
# 4  Harper Lee's classic novel of a lawyer in the ...
#
#                                               genres  \
# 0  Art,Biography,Business,Children's,Christian,Cl...
# 1  Art,Biography,Business,Children's,Christian,Cl...
# 2  Art,Biography,Business,Children's,Christian,Cl...
# 3  Art,Biography,Business,Children's,Christian,Cl...
# 4  Art,Biography,Business,Children's,Christian,Cl...
#
#                                               awards  \
# 0  Mythopoeic Fantasy Award for Children's Litera...
# 1  Mythopoeic Fantasy Award for Children's Litera...
# 2  Georgia Peach Book Award 2007,Buxtehuder Bulle...
# 3  Pulitzer Prize for Fiction 1961,Audie Award fo...
# 4  Pulitzer Prize for Fiction 1961,Audie Award fo...
#
#                                           characters  \
# 0  Draco Malfoy,Ron Weasley,Petunia Dursley,Verno...
# 1  Draco Malfoy,Ron Weasley,Petunia Dursley,Verno...
# 2  Edward Cullen,Jacob Black,Laurent,Renee,Bella ...
# 3  Scout Finch,Atticus Finch,Jem Finch,Arthur Rad...
# 4  Scout Finch,Atticus Finch,Jem Finch,Arthur Rad...
#
#                                               places  ...       publish_date  \
# 0  London, England,Hogwarts School of Witchcraft ...  ...   October 4th 2004
# 1  London, England,Hogwarts School of Witchcraft ...  ...  November 1st 2003
# 2  Forks, Washington,Phoenix, Arizona,Washington ...  ...               2005
# 3                           Maycomb, Alabama,Alabama  ...  October 17th 2006
# 4                           Maycomb, Alabama,Alabama  ...   January 1st 1962
#
#   num_pages num_ratings num_reviews avg_rating   rated_1   rated_2    rated_3  \
# 0     223.0   7437005.0    117859.0       4.48  126396.0  147247.0   627970.0
# 1     309.0   7434783.0    117823.0       4.48  126344.0  147184.0   627803.0
# 2     544.0   5173079.0    106718.0       3.61  562807.0  560978.0  1052619.0
# 3     323.0   4712812.0     94358.0       4.28   85019.0  156544.0   598802.0
# 4     284.0   4712812.0     94358.0       4.28   85019.0  156544.0   598802.0
#
#      rated_4    rated_5
# 0  1694668.0  4840724.0
# 1  1694206.0  4839246.0
# 2  1164865.0  1831810.0
# 3  1395089.0  2477358.0
# 4  1395089.0  2477358.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 3. 🧹 Text Preprocessing
#
# Before we can train word embedding models, we need to prepare the raw book metadata.
#
# Book metadata usually contains a mixture of useful words, punctuation, repeated terms, numbers, and common words such as *the*, *and*, or *is*. These extra elements can make training less effective, so we first convert the raw text into a cleaner and more consistent format.
# is Step
#
# The goal of this section is to transform each book record into a clean list of meaningful tokens.
#
# For example, a raw sentence like:
#
# > A fantasy story about a young wizard, friendship, school, magic, and courage.
#
# may become something like:
#
# ```text
# ["fantasy", "story", "young", "wizard", "friendship", "school", "magic", "courage"]

# %%
# A compact English stopword list.
STOPWORDS = {
    "i", "me", "my", "myself", "we", "our", "ours", "ourselves",
    "you", "your", "yours", "yourself", "yourselves",
    "he", "him", "his", "himself", "she", "her", "hers", "herself",
    "it", "its", "itself", "they", "them", "their", "theirs", "themselves",
    "what", "which", "who", "whom", "this", "that", "these", "those",
    "am", "is", "are", "was", "were", "be", "been", "being",
    "have", "has", "had", "having", "do", "does", "did", "doing",
    "a", "an", "the", "and", "but", "if", "or", "because", "as",
    "until", "while", "of", "at", "by", "for", "with", "about",
    "against", "between", "into", "through", "during", "before",
    "after", "above", "below", "to", "from", "up", "down", "in",
    "out", "on", "off", "over", "under", "again", "further",
    "then", "once", "here", "there", "when", "where", "why", "how",
    "all", "any", "both", "each", "few", "more", "most", "other",
    "some", "such", "no", "nor", "not", "only", "own", "same",
    "so", "than", "too", "very", "s", "t", "can", "will", "just",
    "don", "should", "now",
}

DOMAIN_STOPWORDS = {
    "title", "titl", "author", "description", "descript",
    "genre", "genres", "genr", "place", "places",
    "goodreads", "goodread", "page", "pages",
    "book", "books", "edition", "editions",
    "isbn", "cover", "paperback", "hardcover", "kindle", "ebook",
}

# TODO completed: merge both stopword sets
ALL_STOPWORDS = STOPWORDS | DOMAIN_STOPWORDS

USE_STEMMING = False
stemmer = None
USE_LEMMATIZATION = True

lemmatizer = None
WORDNET_AVAILABLE = False

if USE_LEMMATIZATION:
    try:
        import nltk
        from nltk.stem import WordNetLemmatizer
        nltk.download("wordnet", quiet=True)
        nltk.download("omw-1.4", quiet=True)
        lemmatizer = WordNetLemmatizer()   # TODO completed
        WORDNET_AVAILABLE = True
    except Exception:
        lemmatizer = None
        WORDNET_AVAILABLE = False
        print("WordNet is not available. Continuing without lemmatization.")


def normalize_token(token):
    """Normalize one token."""
    token = token.lower()   # TODO completed: lowercase

    if USE_LEMMATIZATION and lemmatizer is not None:
        token = lemmatizer.lemmatize(token)   # TODO completed

    return token   # TODO completed


print(f"Number of general stopwords: {len(STOPWORDS)}")
print(f"Number of domain stopwords: {len(DOMAIN_STOPWORDS)}")
print(f"Total stopwords used: {len(ALL_STOPWORDS)}")
print(f"Stemming enabled: {USE_STEMMING}")
print(f"Lemmatization enabled: {USE_LEMMATIZATION and WORDNET_AVAILABLE}")
# Out:
# Number of general stopwords: 127
# Number of domain stopwords: 24
# Total stopwords used: 151
# Stemming enabled: False
# Lemmatization enabled: True

# %%
class DataPreprocessor:
    """
    Converts book metadata into a clean tokenized corpus.
    Each row of the dataset becomes one cleaned sentence.
    """

    def __init__(self, stopwords=None):
        self.stopwords = stopwords if stopwords is not None else set()

    def normalize_token(self, token):
        """Normalize one token with optional lemmatization / stemming."""
        if lemmatizer is not None:
            try:
                token = lemmatizer.lemmatize(token)   # TODO completed
            except Exception:
                pass

        if stemmer is not None:
            try:
                token = stemmer.stem(token)   # TODO completed
            except Exception:
                pass

        return token

    def clean_text(self, text):
        """Clean one string and return a cleaned string."""
        if pd.isna(text):
            return ""

        text = str(text).lower()
        text = re.sub(r"[^a-z\s]", " ", text)

        words = text.split()
        cleaned_words = []

        for word in words:
            if word in self.stopwords:
                continue
            if len(word) <= 2:
                continue
            # TODO completed: normalize and collect token
            normalized = self.normalize_token(word)
            cleaned_words.append(normalized)

        return " ".join(cleaned_words)

    def build_corpus(self, df):
        """Combine metadata columns and return cleaned lines + tokenized sentences."""
        required_columns = ["title", "author", "description", "genres", "places"]
        missing = [col for col in required_columns if col not in df.columns]
        if missing:
            raise ValueError(f"Missing required columns: {missing}")

        combined_text = (
            "title " + df["title"].fillna("").astype(str) + " "
            "author " + df["author"].fillna("").astype(str) + " "
            "description " + df["description"].fillna("").astype(str) + " "
            "genres " + df["genres"].fillna("").astype(str) + " "
            "places " + df["places"].fillna("").astype(str)
        )

        cleaned_lines = []
        tokenized_sentences = []

        for line in combined_text:
            cleaned = self.clean_text(line)   # TODO completed
            if cleaned:
                cleaned_lines.append(cleaned)                  # TODO completed
                tokenized_sentences.append(cleaned.split())

        return cleaned_lines, tokenized_sentences   # TODO completed

# %%
preprocessor = DataPreprocessor(stopwords=STOPWORDS)

cleaned_lines, tokenized_sentences = preprocessor.build_corpus(books_df)

print(f"Number of cleaned sentences: {len(cleaned_lines)}")
print("\nExample cleaned sentence:")
print(cleaned_lines[0])
# Out:
# Number of cleaned sentences: 3000
#
# Example cleaned sentence:
# title harry potter philosopher stone author rowling description letter arrives unhappy ordinary harry potter decade old secret revealed parent wizard killed dark lord curse harry baby somehow survived escaping unbearable muggle guardian hogwarts wizarding school brimming ghost enchantment harry stumble sinister adventure letter arrives unhappy ordinary harry potter decade old secret revealed parent wizard killed dark lord curse harry baby somehow survived escaping unbearable muggle guardian hogwarts wizarding school brimming ghost enchantment harry stumble sinister adventure find three headed dog guarding room third floor hears missing stone astonishing power could valuable dangerous front flap genre art biography business child christian classic comic cookbook ebooks fantasy fiction graphic novel historical fiction history horror memoir music mystery nonfiction poetry psychology romance science science fiction self help sport thriller travel young adult art biography business child christian classic comic cookbook ebooks fantasy fiction graphic novel historical fiction history horror memoir music mystery nonfiction poetry psychology romance science science fiction self help sport thriller travel young adult goodreads transgender book page goodreads transgender book page fantasy fiction young adult fantasy magic childrens childrens middle grade adventure classic audiobook science fiction fantasy place london england hogwarts school witchcraft wizardry hogwarts school witchcraft wizardry

# %% [markdown]
# The cleaned corpus is now ready for embedding training. Each sentence is represented as a list of tokens.

# %% [markdown]
# ## 4. Vocabulary and Corpus Statistics
#
# Before training, it is useful to inspect the vocabulary.
#
# The vocabulary is the set of unique tokens in the cleaned corpus. Word embedding models learn one vector per vocabulary item.

# %%
from collections import Counter

# TODO completed: count all tokens across all sentences
token_counts = Counter(
    token
    for sentence in tokenized_sentences
    for token in sentence
)

vocab = set(token_counts.keys())    # TODO completed
vocab_size = len(vocab)              # TODO completed

print(f"Vocabulary size: {vocab_size}")
print("Most common tokens:")
token_counts.most_common(15)
# Out:
# Vocabulary size: 22521
# Most common tokens:
# [('fiction', 23748),
#  ('science', 13336),
#  ('classic', 9477),
#  ('novel', 9197),
#  ('historical', 8688),
#  ('fantasy', 8462),
#  ('adult', 7706),
#  ('young', 7601),
#  ('mystery', 7560),
#  ('thriller', 7113),
#  ('history', 6926),
#  ('romance', 6876),
#  ('child', 6510),
#  ('biography', 6502),
#  ('nonfiction', 6483)]

# %%
plt.figure(figsize=(10, 4))
top_words = token_counts.most_common(20)
plt.bar([word for word, count in top_words], [count for word, count in top_words])
plt.xticks(rotation=45, ha="right")
plt.title("Top 20 Tokens in the Cleaned Corpus")
plt.xlabel("Token")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Embedding Visualization Helper
#
# Word embeddings usually have many dimensions, such as 40 or 100. Since we cannot directly plot 40-dimensional or 100-dimensional vectors, we reduce them to 2 dimensions.
#
# This notebook uses **PCA** when available. It is a simple SVD-based reduction.

# %%
def reduce_to_2d(matrix):
    """Reduce a matrix of word vectors to two dimensions using PCA."""
    matrix = np.asarray(matrix, dtype=np.float64)

    if matrix.ndim != 2:
        raise ValueError("Input matrix must be a 2D array.")
    if matrix.shape[0] < 2:
        raise ValueError("At least two vectors are required for PCA.")

    # Step 1: Center the matrix
    mean_vector = matrix.mean(axis=0)       # TODO completed
    centered_matrix = matrix - mean_vector  # TODO completed

    # Step 2: Covariance matrix
    covariance_matrix = np.cov(centered_matrix.T)   # TODO completed

    # Step 3: Eigen-decomposition (eigh for symmetric matrix)
    eigenvalues, eigenvectors = np.linalg.eigh(covariance_matrix)   # TODO completed

    # Step 4: Sort eigenvectors by eigenvalue (largest first)
    sorted_indices = np.argsort(eigenvalues)[::-1]   # TODO completed
    top_component_indices = sorted_indices[:2]         # TODO completed
    top_components = eigenvectors[:, top_component_indices]   # TODO completed

    # Step 5: Project
    reduced_matrix = centered_matrix @ top_components   # TODO completed

    return reduced_matrix   # TODO completed


class VectorVisualizer:
    """Visualizes selected word vectors in a 2D plot."""

    def __init__(self, word_to_vec):
        self.word_to_vec = word_to_vec

    def visualize(self, target_words, title="2D Projection of Word Vectors"):
        vectors = []
        labels = []

        for word in target_words:
            if word in self.word_to_vec:
                vectors.append(self.word_to_vec[word])   # TODO completed
                labels.append(word)                       # TODO completed
            else:
                print(f"Warning: '{word}' was not found in the vocabulary.")

        if len(vectors) < 2:
            print("At least two known words are needed to create a plot.")
            return

        matrix = np.array(vectors)    # TODO completed
        reduced = reduce_to_2d(matrix)  # TODO completed

        plt.figure(figsize=(10, 7))
        plt.scatter(reduced[:, 0], reduced[:, 1])

        for i, label in enumerate(labels):
            plt.annotate(
                label,
                (reduced[i, 0], reduced[i, 1]),
                xytext=(5, 5),
                textcoords="offset points",
            )

        plt.title(title)
        plt.xlabel("Principal Component 1")
        plt.ylabel("Principal Component 2")
        plt.grid(True)
        plt.show()

# %% [markdown]
# ## 6. Word2Vec from Scratch
#
# This section implements a small skip-gram Word2Vec model from scratch.
#
# ### Skip-gram idea
#
# For each center word, we try to predict nearby context words.
#
# Example sentence:
#
# ```text
# russian novel family history love
# ```
#
# With a window size of 2, the center word `family` has context words:
#
# ```text
# russian novel history love
# ```
#
# ### Negative sampling idea
#
# Instead of comparing the center word against every word in the vocabulary, we train on:
#
# - one real context word,
# - several randomly sampled incorrect context words.
#
# The model learns to assign a high score to real pairs and a low score to negative pairs.

# %%
class SkipGramDataset:
    """Builds vocabulary and skip-gram training pairs."""

    def __init__(self, sentences, window_size=2):
        self.sentences = [s for s in sentences if len(s) > 1]
        self.window_size = window_size
        self.build_vocab()
        self.generate_pairs()

    def build_vocab(self):
        # TODO completed: build word<->idx mappings
        vocab = sorted(set(token for sentence in self.sentences for token in sentence))
        self.word2idx = {word: idx for idx, word in enumerate(vocab)}
        self.idx2word = {idx: word for idx, word in enumerate(vocab)}
        self.vocab_size = len(vocab)

    def generate_pairs(self):
        """Generate center-context training pairs."""
        self.training_pairs = []

        for sentence in self.sentences:
            indexed_sentence = [self.word2idx[word] for word in sentence]

            for center_pos, center_word in enumerate(indexed_sentence):
                start = max(0, center_pos - self.window_size)         # TODO completed
                end = min(len(indexed_sentence), center_pos + self.window_size + 1)  # TODO completed

                for context_pos in range(start, end):
                    if context_pos == center_pos:
                        continue
                    context_word = indexed_sentence[context_pos]   # TODO completed
                    self.training_pairs.append((center_word, context_word))

    def get_negative_samples(self, positive_idx, k=5):
        """Randomly sample k negative examples."""
        negatives = []
        while len(negatives) < k:
            sample = random.randint(0, self.vocab_size - 1)   # TODO completed
            if sample != positive_idx:
                negatives.append(sample)   # TODO completed
        return negatives

# %%
class ScratchWord2Vec:
    """Minimal skip-gram Word2Vec with negative sampling."""

    def __init__(self, vocab_size, embedding_dim=100, learning_rate=0.025):
        self.vocab_size = vocab_size
        self.embedding_dim = embedding_dim
        self.learning_rate = learning_rate

        # TODO completed: random init
        self.W_in  = np.random.uniform(-0.5 / embedding_dim, 0.5 / embedding_dim,
                                        (vocab_size, embedding_dim))
        self.W_out = np.zeros((vocab_size, embedding_dim))

    @staticmethod
    def sigmoid(x):
        return 1 / (1 + np.exp(-np.clip(x, -500, 500)))

    def train_pair(self, center_idx, target_idx, negative_indices):
        """One positive + several negative updates."""
        center_vec = self.W_in[center_idx].copy()    # TODO completed
        target_vec = self.W_out[target_idx].copy()   # TODO completed

        # Positive update
        positive_score = np.dot(center_vec, target_vec)    # TODO completed
        positive_pred  = self.sigmoid(positive_score)       # TODO completed
        positive_error = 1.0 - positive_pred                # TODO completed

        self.W_in[center_idx]  += self.learning_rate * positive_error * target_vec
        self.W_out[target_idx] += self.learning_rate * positive_error * center_vec

        # Negative updates
        for neg_idx in negative_indices:
            neg_vec = self.W_out[neg_idx].copy()

            negative_score = np.dot(center_vec, neg_vec)   # TODO completed
            negative_pred  = self.sigmoid(negative_score)   # TODO completed
            negative_error = 0.0 - negative_pred            # TODO completed

            self.W_in[center_idx]  += self.learning_rate * negative_error * neg_vec
            self.W_out[neg_idx]    += self.learning_rate * negative_error * center_vec

    def get_vector(self, idx):
        return self.W_in[idx]

    def save(self, path, word2idx, idx2word):
        # TODO completed
        data = {
            "W_in":    self.W_in,
            "W_out":   self.W_out,
            "word2idx": word2idx,
            "idx2word": idx2word,
        }
        with open(path, "wb") as f:
            pickle.dump(data, f)

    @classmethod
    def load(cls, path):
        with open(path, "rb") as f:
            data = pickle.load(f)

        vocab_size    = len(data["word2idx"])   # TODO completed
        embedding_dim = data["W_in"].shape[1]   # TODO completed

        model = cls(vocab_size, embedding_dim)  # TODO completed
        model.W_in    = data["W_in"]            # TODO completed
        model.W_out   = data["W_out"]           # TODO completed
        model.word2idx = data["word2idx"]        # TODO completed
        model.idx2word = data["idx2word"]        # TODO completed
        return model

# %%
class Trainer:
    """Training loop for the scratch Word2Vec model."""

    def __init__(self, model, dataset, epochs=5, negative_samples=5, max_pairs=None):
        self.model = model
        self.dataset = dataset
        self.epochs = epochs
        self.negative_samples = negative_samples
        self.max_pairs = max_pairs

    def train(self):
        pairs = self.dataset.training_pairs

        if self.max_pairs is not None and self.max_pairs < len(pairs):
            pairs = random.sample(pairs, self.max_pairs)   # TODO completed

        for epoch in range(self.epochs):
            print(f"Epoch {epoch + 1}/{self.epochs}")

            for center_idx, target_idx in tqdm(pairs, leave=False):
                # TODO completed: get negative samples
                negative_indices = self.dataset.get_negative_samples(
                    target_idx, k=self.negative_samples
                )
                self.model.train_pair(
                    center_idx=center_idx,
                    target_idx=target_idx,
                    negative_indices=negative_indices,
                )

# %% [markdown]
# ### Train the scratch Word2Vec model
#
# The training settings below are intentionally small enough to run quickly in a notebook.

# %%
scratch_dataset = SkipGramDataset(
    sentences=tokenized_sentences,
    window_size=3,
)

scratch_model = ScratchWord2Vec(
    vocab_size=scratch_dataset.vocab_size,
    embedding_dim=100,
    learning_rate=0.01,
)

scratch_trainer = Trainer(
    model=scratch_model,
    dataset=scratch_dataset,
    epochs=5,
    negative_samples=5,
    max_pairs=None,
)

print(f"Vocabulary size: {scratch_dataset.vocab_size}")
print(f"Number of skip-gram pairs: {len(scratch_dataset.training_pairs)}")

scratch_trainer.train()
print("Scratch Word2Vec training complete.")
# Out:
# Vocabulary size: 22521
# Number of skip-gram pairs: 3490008
# Epoch 1/5
#   0%|          | 0/3490008 [00:00<?, ?it/s]
# Epoch 2/5
#   0%|          | 0/3490008 [00:00<?, ?it/s]
# Epoch 3/5
#   0%|          | 0/3490008 [00:00<?, ?it/s]
# Epoch 4/5
#   0%|          | 0/3490008 [00:00<?, ?it/s]
# Epoch 5/5
#   0%|          | 0/3490008 [00:00<?, ?it/s]
# Scratch Word2Vec training complete.

# %% [markdown]
# ## 7. Testing Semantic Consistency with Odd-One-Out Questions
#
# After training word embeddings, we need a simple way to inspect whether the model has learned meaningful relationships between words.
#
#
# In each question, the model receives a small group of words. Most of the words should belong to the same semantic category, while one word should be less related to the others.
#
# For example:
#
# ```text
# fiction, novel, story, business

# %%
class ScratchModelTester:
    """Tests scratch Word2Vec embeddings."""

    def __init__(self, model, word2idx, idx2word):
        self.model = model
        self.word2idx = word2idx
        self.idx2word = idx2word

        # TODO completed: store all learned vectors
        self.word_to_vec = {
            idx2word[idx]: model.get_vector(idx)
            for idx in range(len(idx2word))
        }

    def _to_numpy(self, vector):
        if hasattr(vector, "detach"):
            vector = vector.detach().cpu().numpy()
        return np.asarray(vector, dtype=np.float64)   # TODO completed

    def get_vector(self, word):
        if word not in self.word_to_vec:
            return None
        return self._to_numpy(self.word_to_vec[word])   # TODO completed

    def cosine_similarity(self, vector_a, vector_b):
        norm_a = np.linalg.norm(vector_a)   # TODO completed
        norm_b = np.linalg.norm(vector_b)   # TODO completed
        if norm_a == 0 or norm_b == 0:
            return 0.0
        return float(np.dot(vector_a, vector_b) / (norm_a * norm_b))   # TODO completed

    def find_similar_words(self, word, top_n=10):
        target_vector = self.get_vector(word)   # TODO completed
        if target_vector is None:
            return f"'{word}' was not found in the vocabulary."

        similarities = []
        for other_word, other_vector in self.word_to_vec.items():
            if other_word == word:
                continue
            similarity = self.cosine_similarity(target_vector, self._to_numpy(other_vector))   # TODO completed
            similarities.append((other_word, similarity))

        similarities.sort(key=lambda item: item[1], reverse=True)
        return similarities[:top_n]   # TODO completed

    def odd_one_out(self, words):
        """Find the word that does not belong in the group."""
        vectors = {}
        for word in words:
            vector = self.get_vector(word)
            if vector is None:
                return {"prediction": None, "error": f"'{word}' was not found in the vocabulary.", "scores": None}
            vectors[word] = vector

        scores = {}
        for word in words:
            similarities = []
            for other_word in words:
                if word == other_word:
                    continue
                similarity = self.cosine_similarity(vectors[word], vectors[other_word])   # TODO completed
                similarities.append(similarity)
            scores[word] = np.mean(similarities)

        prediction = min(scores, key=scores.get)   # TODO completed
        return {"prediction": prediction, "error": None, "scores": scores}   # TODO completed

    def get_vector_dict(self):
        return self.word_to_vec

# %%
odd_one_out_questions = [
    #Easy tests
    (["england", "london", "british", "dostoevsky"], "dostoevsky"),
    (["harry", "potter", "hogwarts", "tolstoy"], "tolstoy"),
    (["jane", "austen", "darcy", "wizard"], "wizard"),
    (["russia", "russian", "dostoevsky", "romance"], "romance"),
    (["america", "american", "united", "hogwarts"], "hogwarts"),
    (["france", "paris", "european", "vampire"], "vampire"),
    (["king", "queen", "lord", "british"], "british"),
    (["school", "student", "teacher", "tolstoy"], "tolstoy"),
    (["science", "fiction", "fantasy", "london"], "london"),
    (["mystery", "thriller", "crime", "austen"], "austen"),
    #Harder tests
    (["fiction", "novel", "story", "business"], "business"),
    (["fantasy", "magic", "fiction", "biography"], "biography"),
    (["mystery", "thriller", "crime", "poetry"], "poetry"),
    (["history", "historical", "century", "romance"], "romance"),
    (["biography", "memoir", "life", "horror"], "horror"),
    (["child", "young", "adult", "business"], "business"),
    (["austen", "fitzgerald", "miller", "travel"], "travel"),
    (["romance", "love", "family", "science"], "science"),
    (["music", "art", "poetry", "thriller"], "thriller"),
    (["business", "psychology", "self", "fantasy"], "fantasy"),
]

# %%
scratch_tester = ScratchModelTester(
    model=scratch_model,
    word2idx=scratch_dataset.word2idx,
    idx2word=scratch_dataset.idx2word,
)

correct = 0
total = 0

for words, expected in odd_one_out_questions:
    result = scratch_tester.odd_one_out(words)   # TODO completed

    print(f"Words: {words}")
    print(f"Expected odd word: {expected}")

    if result["error"] is not None:
        print(f"Model output: {result['error']}")
    else:
        prediction = result["prediction"]              # TODO completed
        is_correct = prediction == expected            # TODO completed

        correct += 1 if is_correct else 0             # TODO completed
        total += 1

        print(f"Model output: {prediction}")
        print(f"Correct: {is_correct}")

        print("Scores, lower means more likely to be odd:")
        for word, score in sorted(result["scores"].items(), key=lambda item: item[1]):
            print(f"  {word:12s} {score:.4f}")

    print("-" * 60)

print(f"Final score: {correct}/{total}")
# Out:
# Words: ['england', 'london', 'british', 'dostoevsky']
# Expected odd word: dostoevsky
# Model output: dostoevsky
# Correct: True
# Scores, lower means more likely to be odd:
#   dostoevsky   0.5845
#   england      0.7296
#   london       0.7689
#   british      0.7714
# ------------------------------------------------------------
# Words: ['harry', 'potter', 'hogwarts', 'tolstoy']
# Expected odd word: tolstoy
# Model output: hogwarts
# Correct: False
# Scores, lower means more likely to be odd:
#   hogwarts     0.8894
#   tolstoy      0.9365
#   harry        0.9509
#   potter       0.9527
# ------------------------------------------------------------
# Words: ['jane', 'austen', 'darcy', 'wizard']
# Expected odd word: wizard
# Model output: wizard
# Correct: True
# Scores, lower means more likely to be odd:
#   wizard       0.8768
#   jane         0.8905
#   austen       0.9284
#   darcy        0.9356
# ------------------------------------------------------------
# Words: ['russia', 'russian', 'dostoevsky', 'romance']
# Expected odd word: romance
# Model output: romance
# Correct: True
# Scores, lower means more likely to be odd:
#   romance      0.6622
#   dostoevsky   0.7407
#   russian      0.8332
#   russia       0.8605
# ------------------------------------------------------------
# Words: ['america', 'american', 'united', 'hogwarts']
# Expected odd word: hogwarts
# Model output: american
# Correct: False
# Scores, lower means more likely to be odd:
#   american     0.7636
#   hogwarts     0.7786
#   united       0.8180
#   america      0.8473
# ------------------------------------------------------------
# Words: ['france', 'paris', 'european', 'vampire']
# Expected odd word: vampire
# Model output: vampire
# Correct: True
# Scores, lower means more likely to be odd:
#   vampire      0.7870
#   european     0.8122
#   paris        0.8633
#   france       0.9010
# ------------------------------------------------------------
# Words: ['king', 'queen', 'lord', 'british']
# Expected odd word: british
# Model output: british
# Correct: True
# Scores, lower means more likely to be odd:
#   british      0.5858
#   king         0.6809
#   lord         0.7619
#   queen        0.7946
# ------------------------------------------------------------
# Words: ['school', 'student', 'teacher', 'tolstoy']
# Expected odd word: tolstoy
# Model output: school
# Correct: False
# Scores, lower means more likely to be odd:
#   school       0.5387
#   tolstoy      0.7005
#   student      0.7305
#   teacher      0.7958
# ------------------------------------------------------------
# Words: ['science', 'fiction', 'fantasy', 'london']
# Expected odd word: london
# Model output: london
# Correct: True
# Scores, lower means more likely to be odd:
#   london       0.4449
#   science      0.6592
#   fiction      0.6865
#   fantasy      0.7104
# ------------------------------------------------------------
# Words: ['mystery', 'thriller', 'crime', 'austen']
# Expected odd word: austen
# Model output: austen
# Correct: True
# Scores, lower means more likely to be odd:
#   austen       0.5759
#   thriller     0.7327
#   mystery      0.7477
#   crime        0.7705
# ------------------------------------------------------------
# Words: ['fiction', 'novel', 'story', 'business']
# Expected odd word: business
# Model output: story
# Correct: False
# Scores, lower means more likely to be odd:
#   story        0.3585
#   business     0.4468
#   fiction      0.5086
#   novel        0.5254
# ------------------------------------------------------------
# Words: ['fantasy', 'magic', 'fiction', 'biography']
# Expected odd word: biography
# Model output: biography
# Correct: True
# Scores, lower means more likely to be odd:
#   biography    0.4902
#   magic        0.5825
#   fiction      0.6654
#   fantasy      0.6965
# ------------------------------------------------------------
# Words: ['mystery', 'thriller', 'crime', 'poetry']
# Expected odd word: poetry
# Model output: poetry
# Correct: True
# Scores, lower means more likely to be odd:
#   poetry       0.7682
#   crime        0.7902
#   thriller     0.8057
#   mystery      0.8474
# ------------------------------------------------------------
# Words: ['history', 'historical', 'century', 'romance']
# Expected odd word: romance
# Model output: century
# Correct: False
# Scores, lower means more likely to be odd:
#   century      0.6218
#   history      0.6785
#   romance      0.6797
#   historical   0.7520
# ------------------------------------------------------------
# Words: ['biography', 'memoir', 'life', 'horror']
# Expected odd word: horror
# Model output: life
# Correct: False
# Scores, lower means more likely to be odd:
#   life         0.3824
#   biography    0.5395
#   horror       0.6461
#   memoir       0.6756
# ------------------------------------------------------------
# Words: ['child', 'young', 'adult', 'business']
# Expected odd word: business
# Model output: young
# Correct: False
# Scores, lower means more likely to be odd:
#   young        0.6481
#   child        0.6909
#   business     0.7326
#   adult        0.7464
# ------------------------------------------------------------
# Words: ['austen', 'fitzgerald', 'miller', 'travel']
# Expected odd word: travel
# Model output: travel
# Correct: True
# Scores, lower means more likely to be odd:
#   travel       0.4958
#   fitzgerald   0.7955
#   austen       0.8277
#   miller       0.8278
# ------------------------------------------------------------
# Words: ['romance', 'love', 'family', 'science']
# Expected odd word: science
# Model output: family
# Correct: False
# Scores, lower means more likely to be odd:
#   family       0.4737
#   science      0.5485
#   love         0.5576
#   romance      0.5920
# ------------------------------------------------------------
# Words: ['music', 'art', 'poetry', 'thriller']
# Expected odd word: thriller
# Model output: art
# Correct: False
# Scores, lower means more likely to be odd:
#   art          0.5222
#   thriller     0.6919
#   poetry       0.7188
#   music        0.7421
# ------------------------------------------------------------
# Words: ['business', 'psychology', 'self', 'fantasy']
# Expected odd word: fantasy
# Model output: fantasy
# Correct: True
# Scores, lower means more likely to be odd:
#   fantasy      0.7018
#   business     0.7595
#   self         0.7706
#   psychology   0.8332
# ------------------------------------------------------------
# Final score: 11/20

# %% [markdown]
# ## Model Performance Note
#
# The scratch Word2Vec model has learned from the training corpus, but its results are still limited. This is expected because the dataset is relatively small and the model is trained from scratch without the optimizations used in larger embedding libraries.
#
# Some predictions may be reasonable, while others may look noisy or unrelated. This does not mean the implementation is wrong; it shows that word embeddings need enough clean text and repeated context patterns to learn strong semantic relationships.
#
# To improve the results, you can experiment with:
#
# - increasing the number of training epochs,
# - using a larger embedding dimension,
# - cleaning the corpus more carefully,
# - training on a larger dataset.

# %% [markdown]
# ## 8. Visualizing Scratch Word2Vec Vectors
#
# The plot below projects selected word vectors into 2D.
#
# Words that appear near each other have vectors that are relatively similar under the learned embedding space.

# %%
words_to_visualize = [
    "russian",
    "russia",
    "egypt",
    "africa",
    "america",
    "author",
    "friedrich",
    "albert",
    "rowl",
    "nietzsch",
    "camu",
    "jane",
    "austen",
]

# %%
scratch_visualizer = VectorVisualizer(scratch_tester.get_vector_dict())
scratch_visualizer.visualize(
    target_words=words_to_visualize,
    title="Scratch Word2Vec: 2D Word Vector Projection",
)
# Out:
# Warning: 'nietzsch' was not found in the vocabulary.
# Warning: 'camu' was not found in the vocabulary.

# %% [markdown]
# ## 9. FastText with Gensim
#
# FastText improves on basic Word2Vec by using **subword information**.
#
# Instead of learning only a vector for each whole word, FastText also learns from character n-grams. This helps the model handle:
#
# - rare words,
# - misspellings,
# - related word forms,
# - words that share roots.
#
# This section trains a FastText model using Gensim.

# %%
try:
    from gensim.models import FastText as GensimFastText

    GENSIM_AVAILABLE = True
except Exception as e:
    GensimFastText = None
    GENSIM_AVAILABLE = False
    print("Gensim is not available in this environment.")
    print("Error:", e)

print(f"Gensim available: {GENSIM_AVAILABLE}")
# Out:
# Gensim available: True

# %%
from time import perf_counter
from tqdm.auto import tqdm
from gensim.models.callbacks import CallbackAny2Vec

class TqdmEpochCallback(CallbackAny2Vec):
    def __init__(self, total_epochs):
        self.progress_bar = tqdm(total=total_epochs, desc="Training Gensim FastText")

    def on_epoch_end(self, model):
        self.progress_bar.update(1)

    def on_train_end(self, model):
        self.progress_bar.close()


gensim_fasttext_model = None

if GENSIM_AVAILABLE:
    GENSIM_VECTOR_SIZE = 40
    GENSIM_WINDOW_SIZE = 10
    GENSIM_MIN_COUNT   = 1
    GENSIM_WORKERS     = 1
    GENSIM_EPOCHS      = 100

    gensim_fasttext_model = GensimFastText(
        vector_size=GENSIM_VECTOR_SIZE,
        window=GENSIM_WINDOW_SIZE,
        min_count=GENSIM_MIN_COUNT,
        workers=GENSIM_WORKERS,
        seed=RANDOM_SEED,
    )

    gensim_fasttext_model.build_vocab(corpus_iterable=tokenized_sentences)

    print("Starting Gensim FastText training...")
    print(f"Vocabulary size: {len(gensim_fasttext_model.wv.index_to_key)}")
    print(f"Epochs: {GENSIM_EPOCHS}")

    start_time = perf_counter()

    gensim_fasttext_model.train(
        corpus_iterable=tokenized_sentences,
        total_examples=gensim_fasttext_model.corpus_count,
        epochs=GENSIM_EPOCHS,
        callbacks=[TqdmEpochCallback(GENSIM_EPOCHS)],
    )

    elapsed_time = perf_counter() - start_time   # TODO completed

    print("Gensim FastText training complete.")
    print(f"Training time: {elapsed_time:.2f} seconds")

else:
    print("Skipping Gensim FastText training because Gensim is unavailable.")
# Out:
# Starting Gensim FastText training...
# Vocabulary size: 22521
# Epochs: 100
# Training Gensim FastText:   0%|          | 0/100 [00:00<?, ?it/s]
# Gensim FastText training complete.
# Training time: 584.65 seconds

# %%
class GensimFastTextTester:
    """Tests a trained Gensim FastText model."""

    def __init__(self, model):
        self.model = model
        self.word_to_vec = {
            word: np.asarray(self.model.wv[word], dtype=np.float64)
            for word in self.model.wv.index_to_key
        }

    def get_vector(self, word):
        try:
            return np.asarray(self.model.wv[word], dtype=np.float64)
        except KeyError:
            return None

    def cosine_similarity(self, vector_a, vector_b):
        norm_a = np.linalg.norm(vector_a)   # TODO completed
        norm_b = np.linalg.norm(vector_b)   # TODO completed
        if norm_a == 0 or norm_b == 0:
            return 0.0
        return float(np.dot(vector_a, vector_b) / (norm_a * norm_b))   # TODO completed

    def find_similar_words(self, word, top_n=10):
        try:
            return self.model.wv.most_similar(word, topn=top_n)
        except KeyError:
            return f"'{word}' was not found in the vocabulary."

    def odd_one_out(self, words):
        vectors = {}
        for word in words:
            vector = self.get_vector(word)
            if vector is None:
                return {"prediction": None, "error": f"'{word}' was not found in the vocabulary.", "scores": None}
            vectors[word] = vector

        scores = {}
        for word in words:
            similarities = []
            for other_word in words:
                if word == other_word:
                    continue
                similarity = self.cosine_similarity(vectors[word], vectors[other_word])   # TODO completed
                similarities.append(similarity)
            scores[word] = np.mean(similarities)

        prediction = min(scores, key=scores.get)   # TODO completed
        return {"prediction": prediction, "error": None, "scores": scores}   # TODO completed

    def get_vector_dict(self):
        return self.word_to_vec

# %%
if gensim_fasttext_model is not None:
    gensim_tester = GensimFastTextTester(gensim_fasttext_model)

    correct = 0
    total = 0

    for words, expected in odd_one_out_questions:
        result = gensim_tester.odd_one_out(words)

        print(f"Words: {words}")
        print(f"Expected odd word: {expected}")

        if result["error"] is not None:
            print(f"Model output: {result['error']}")
        else:
            prediction = result["prediction"]    # TODO completed
            is_correct = prediction == expected  # TODO completed

            correct += 1 if is_correct else 0   # TODO completed
            total += 1

            print(f"Model output: {prediction}")
            print(f"Correct: {is_correct}")

            print("Scores, lower means more likely to be odd:")
            for word, score in sorted(result["scores"].items(), key=lambda item: item[1]):
                print(f"  {word:12s} {score:.4f}")

        print("-" * 60)

    print(f"Final score: {correct}/{total}")

    gensim_visualizer = VectorVisualizer(gensim_tester.get_vector_dict())
    gensim_visualizer.visualize(
        target_words=words_to_visualize,
        title="Gensim FastText: 2D Word Vector Projection",
    )

else:
    print("No Gensim FastText model is available to test.")
# Out:
# Words: ['england', 'london', 'british', 'dostoevsky']
# Expected odd word: dostoevsky
# Model output: dostoevsky
# Correct: True
# Scores, lower means more likely to be odd:
#   dostoevsky   0.0323
#   england      0.3400
#   british      0.3452
#   london       0.3494
# ------------------------------------------------------------
# Words: ['harry', 'potter', 'hogwarts', 'tolstoy']
# Expected odd word: tolstoy
# Model output: tolstoy
# Correct: True
# Scores, lower means more likely to be odd:
#   tolstoy      -0.1549
#   hogwarts     0.2698
#   potter       0.3750
#   harry        0.3758
# ------------------------------------------------------------
# Words: ['jane', 'austen', 'darcy', 'wizard']
# Expected odd word: wizard
# Model output: wizard
# Correct: True
# Scores, lower means more likely to be odd:
#   wizard       -0.0090
#   jane         0.3367
#   austen       0.3380
#   darcy        0.3779
# ------------------------------------------------------------
# Words: ['russia', 'russian', 'dostoevsky', 'romance']
# Expected odd word: romance
# Model output: romance
# Correct: True
# Scores, lower means more likely to be odd:
#   romance      0.2401
#   dostoevsky   0.2427
#   russian      0.5539
#   russia       0.6110
# ------------------------------------------------------------
# Words: ['america', 'american', 'united', 'hogwarts']
# Expected odd word: hogwarts
# Model output: hogwarts
# Correct: True
# Scores, lower means more likely to be odd:
#   hogwarts     -0.1666
#   united       0.1878
#   america      0.2917
#   american     0.2950
# ------------------------------------------------------------
# Words: ['france', 'paris', 'european', 'vampire']
# Expected odd word: vampire
# Model output: vampire
# Correct: True
# Scores, lower means more likely to be odd:
#   vampire      0.0159
#   paris        0.0933
#   european     0.1330
#   france       0.2282
# ------------------------------------------------------------
# Words: ['king', 'queen', 'lord', 'british']
# Expected odd word: british
# Model output: lord
# Correct: False
# Scores, lower means more likely to be odd:
#   lord         -0.0754
#   british      0.0095
#   queen        0.1910
#   king         0.1970
# ------------------------------------------------------------
# Words: ['school', 'student', 'teacher', 'tolstoy']
# Expected odd word: tolstoy
# Model output: tolstoy
# Correct: True
# Scores, lower means more likely to be odd:
#   tolstoy      -0.0192
#   school       0.1810
#   teacher      0.1855
#   student      0.3260
# ------------------------------------------------------------
# Words: ['science', 'fiction', 'fantasy', 'london']
# Expected odd word: london
# Model output: london
# Correct: True
# Scores, lower means more likely to be odd:
#   london       -0.1161
#   fantasy      0.5311
#   science      0.5390
#   fiction      0.5612
# ------------------------------------------------------------
# Words: ['mystery', 'thriller', 'crime', 'austen']
# Expected odd word: austen
# Model output: austen
# Correct: True
# Scores, lower means more likely to be odd:
#   austen       -0.1910
#   crime        0.0227
#   mystery      0.2349
#   thriller     0.2528
# ------------------------------------------------------------
# Words: ['fiction', 'novel', 'story', 'business']
# Expected odd word: business
# Model output: story
# Correct: False
# Scores, lower means more likely to be odd:
#   story        0.0591
#   business     0.3785
#   fiction      0.4624
#   novel        0.5106
# ------------------------------------------------------------
# Words: ['fantasy', 'magic', 'fiction', 'biography']
# Expected odd word: biography
# Model output: magic
# Correct: False
# Scores, lower means more likely to be odd:
#   magic        0.1395
#   biography    0.5765
#   fantasy      0.5839
#   fiction      0.6167
# ------------------------------------------------------------
# Words: ['mystery', 'thriller', 'crime', 'poetry']
# Expected odd word: poetry
# Model output: crime
# Correct: False
# Scores, lower means more likely to be odd:
#   crime        0.1394
#   poetry       0.4789
#   mystery      0.4963
#   thriller     0.5446
# ------------------------------------------------------------
# Words: ['history', 'historical', 'century', 'romance']
# Expected odd word: romance
# Model output: century
# Correct: False
# Scores, lower means more likely to be odd:
#   century      0.0920
#   history      0.5341
#   romance      0.5499
#   historical   0.6027
# ------------------------------------------------------------
# Words: ['biography', 'memoir', 'life', 'horror']
# Expected odd word: horror
# Model output: life
# Correct: False
# Scores, lower means more likely to be odd:
#   life         -0.3332
#   horror       0.2791
#   memoir       0.2821
#   biography    0.3222
# ------------------------------------------------------------
# Words: ['child', 'young', 'adult', 'business']
# Expected odd word: business
# Model output: child
# Correct: False
# Scores, lower means more likely to be odd:
#   child        0.4246
#   adult        0.4542
#   business     0.4585
#   young        0.4622
# ------------------------------------------------------------
# Words: ['austen', 'fitzgerald', 'miller', 'travel']
# Expected odd word: travel
# Model output: travel
# Correct: True
# Scores, lower means more likely to be odd:
#   travel       -0.1638
#   miller       -0.0772
#   austen       -0.0173
#   fitzgerald   0.0173
# ------------------------------------------------------------
# Words: ['romance', 'love', 'family', 'science']
# Expected odd word: science
# Model output: family
# Correct: False
# Scores, lower means more likely to be odd:
#   family       -0.0591
#   love         0.0036
#   science      0.1397
#   romance      0.1397
# ------------------------------------------------------------
# Words: ['music', 'art', 'poetry', 'thriller']
# Expected odd word: thriller
# Model output: art
# Correct: False
# Scores, lower means more likely to be odd:
#   art          0.3609
#   thriller     0.5017
#   music        0.5095
#   poetry       0.5211
# ------------------------------------------------------------
# Words: ['business', 'psychology', 'self', 'fantasy']
# Expected odd word: fantasy
# Model output: self
# Correct: False
# Scores, lower means more likely to be odd:
#   self         0.5006
#   business     0.5654
#   psychology   0.6616
#   fantasy      0.6672
# ------------------------------------------------------------
# Final score: 10/20
# Warning: 'nietzsch' was not found in the vocabulary.
# Warning: 'camu' was not found in the vocabulary.

# %% [markdown]
# ## 10. FastText with the Native `fasttext` Package
#
# The native FastText implementation expects text input as lines of tokens.
#
# Since this notebook already has cleaned lines in memory, we create a temporary text corpus during this cell and use it for training.
#
# This section is optional because the `fasttext` package can require compilation on some systems.

# %%
try:
    import fasttext

    NATIVE_FASTTEXT_AVAILABLE = True
except Exception as e:
    fasttext = None
    NATIVE_FASTTEXT_AVAILABLE = False
    print("The native fasttext package is not available in this environment.")
    print("Error:", e)

print(f"Native fasttext available: {NATIVE_FASTTEXT_AVAILABLE}")
# Out:
# Native fasttext available: True

# %%
from threading import Thread, Event
from time import perf_counter, sleep
import os

native_fasttext_model = None

if NATIVE_FASTTEXT_AVAILABLE:
    NATIVE_VECTOR_SIZE = 40
    NATIVE_WINDOW_SIZE = 10
    NATIVE_EPOCHS      = 25
    NATIVE_MIN_COUNT   = 1

    with tempfile.NamedTemporaryFile(
        mode="w", encoding="utf-8", suffix=".txt", delete=False,
    ) as tmp:
        tmp.write("\n".join(cleaned_lines))
        temp_corpus_path = tmp.name

    stop_progress = Event()

    def show_training_progress():
        with tqdm(desc="Training Native FastText", unit="sec") as progress_bar:
            while not stop_progress.is_set():
                sleep(1)
                progress_bar.update(1)

    progress_thread = Thread(target=show_training_progress, daemon=True)   # TODO completed
    progress_thread.start()

    print("Starting native FastText training...")
    print(f"Vector size: {NATIVE_VECTOR_SIZE}")
    print(f"Window size: {NATIVE_WINDOW_SIZE}")
    print(f"Epochs: {NATIVE_EPOCHS}")
    print(f"Minimum word count: {NATIVE_MIN_COUNT}")

    start_time = perf_counter()   # TODO completed

    try:
        native_fasttext_model = fasttext.train_unsupervised(
            input=temp_corpus_path,
            model="skipgram",
            dim=NATIVE_VECTOR_SIZE,
            ws=NATIVE_WINDOW_SIZE,
            epoch=NATIVE_EPOCHS,
            minCount=NATIVE_MIN_COUNT,
            verbose=0,
        )
    finally:
        stop_progress.set()
        progress_thread.join()
        if os.path.exists(temp_corpus_path):
            os.remove(temp_corpus_path)

    elapsed_time = perf_counter() - start_time   # TODO completed

    print("Native FastText training complete.")
    print(f"Training time: {elapsed_time:.2f} seconds")
    print(f"Vocabulary size: {len(native_fasttext_model.get_words())}")

else:
    print("Skipping native FastText training because the package is unavailable.")
# Out:
# Starting native FastText training...
# Vector size: 40
# Window size: 10
# Epochs: 25
# Minimum word count: 1
# Training Native FastText: 0sec [00:00, ?sec/s]
# Native FastText training complete.
# Training time: 282.25 seconds
# Vocabulary size: 22522

# %%
class NativeFastTextTester:
    """Tests a model trained with the native fasttext package."""

    def __init__(self, model):
        self.model = model
        self.words = self.model.get_words()
        self.word_to_vec = {
            word: np.asarray(self.model.get_word_vector(word), dtype=np.float64)
            for word in self.words
        }

    def get_vector(self, word):
        if word not in self.word_to_vec:
            return None
        return self.word_to_vec[word]   # TODO completed

    def cosine_similarity(self, vector_a, vector_b):
        norm_a = np.linalg.norm(vector_a)   # TODO completed
        norm_b = np.linalg.norm(vector_b)   # TODO completed
        if norm_a == 0 or norm_b == 0:
            return 0.0
        return float(np.dot(vector_a, vector_b) / (norm_a * norm_b))   # TODO completed

    def find_similar_words(self, word, top_n=10):
        target_vector = self.get_vector(word)   # TODO completed
        if target_vector is None:
            return f"'{word}' was not found in the vocabulary."

        similarities = []
        for other_word, other_vector in self.word_to_vec.items():
            if other_word == word:
                continue
            similarity = self.cosine_similarity(target_vector, other_vector)   # TODO completed
            similarities.append((other_word, similarity))

        similarities.sort(key=lambda item: item[1], reverse=True)
        return similarities[:top_n]

    def odd_one_out(self, words):
        vectors = {}
        for word in words:
            vector = self.get_vector(word)
            if vector is None:
                return {"prediction": None, "error": f"'{word}' was not found in the vocabulary.", "scores": None}
            vectors[word] = vector

        scores = {}
        for word in words:
            similarities = []
            for other_word in words:
                if word == other_word:
                    continue
                similarity = self.cosine_similarity(vectors[word], vectors[other_word])   # TODO completed
                similarities.append(similarity)
            scores[word] = np.mean(similarities)

        prediction = min(scores, key=scores.get)   # TODO completed
        return {"prediction": prediction, "error": None, "scores": scores}   # TODO completed

    def get_vector_dict(self):
        return self.word_to_vec

# %%
if native_fasttext_model is not None:
    native_tester = NativeFastTextTester(native_fasttext_model)

    correct = 0
    total = 0

    for words, expected in odd_one_out_questions:
        result = native_tester.odd_one_out(words)   # TODO completed

        print(f"Words: {words}")
        print(f"Expected odd word: {expected}")

        if result["error"] is not None:
            print(f"Model output: {result['error']}")
        else:
            prediction = result["prediction"]    # TODO completed
            is_correct = prediction == expected  # TODO completed

            correct += 1 if is_correct else 0   # TODO completed
            total += 1

            print(f"Model output: {prediction}")
            print(f"Correct: {is_correct}")

            print("Scores, lower means more likely to be odd:")
            for word, score in sorted(result["scores"].items(), key=lambda item: item[1]):
                print(f"  {word:12s} {score:.4f}")

        print("-" * 60)

    print(f"Final score: {correct}/{total}")

    native_visualizer = VectorVisualizer(native_tester.get_vector_dict())
    native_visualizer.visualize(
        target_words=words_to_visualize,
        title="Native FastText: 2D Word Vector Projection",
    )

else:
    print("No native FastText model is available to test.")
# Out:
# Words: ['england', 'london', 'british', 'dostoevsky']
# Expected odd word: dostoevsky
# Model output: dostoevsky
# Correct: True
# Scores, lower means more likely to be odd:
#   dostoevsky   0.2364
#   london       0.5769
#   england      0.5918
#   british      0.6051
# ------------------------------------------------------------
# Words: ['harry', 'potter', 'hogwarts', 'tolstoy']
# Expected odd word: tolstoy
# Model output: tolstoy
# Correct: True
# Scores, lower means more likely to be odd:
#   tolstoy      0.2415
#   potter       0.5973
#   hogwarts     0.6129
#   harry        0.6546
# ------------------------------------------------------------
# Words: ['jane', 'austen', 'darcy', 'wizard']
# Expected odd word: wizard
# Model output: wizard
# Correct: True
# Scores, lower means more likely to be odd:
#   wizard       0.1416
#   darcy        0.4940
#   jane         0.5700
#   austen       0.5826
# ------------------------------------------------------------
# Words: ['russia', 'russian', 'dostoevsky', 'romance']
# Expected odd word: romance
# Model output: romance
# Correct: True
# Scores, lower means more likely to be odd:
#   romance      0.4431
#   dostoevsky   0.6160
#   russian      0.6711
#   russia       0.7300
# ------------------------------------------------------------
# Words: ['america', 'american', 'united', 'hogwarts']
# Expected odd word: hogwarts
# Model output: hogwarts
# Correct: True
# Scores, lower means more likely to be odd:
#   hogwarts     0.2792
#   american     0.5815
#   united       0.6300
#   america      0.6503
# ------------------------------------------------------------
# Words: ['france', 'paris', 'european', 'vampire']
# Expected odd word: vampire
# Model output: vampire
# Correct: True
# Scores, lower means more likely to be odd:
#   vampire      0.2254
#   paris        0.4915
#   european     0.5161
#   france       0.5567
# ------------------------------------------------------------
# Words: ['king', 'queen', 'lord', 'british']
# Expected odd word: british
# Model output: british
# Correct: True
# Scores, lower means more likely to be odd:
#   british      0.3130
#   lord         0.3580
#   queen        0.4705
#   king         0.4910
# ------------------------------------------------------------
# Words: ['school', 'student', 'teacher', 'tolstoy']
# Expected odd word: tolstoy
# Model output: tolstoy
# Correct: True
# Scores, lower means more likely to be odd:
#   tolstoy      0.3521
#   school       0.4695
#   student      0.5421
#   teacher      0.5557
# ------------------------------------------------------------
# Words: ['science', 'fiction', 'fantasy', 'london']
# Expected odd word: london
# Model output: london
# Correct: True
# Scores, lower means more likely to be odd:
#   london       0.5013
#   fantasy      0.8018
#   fiction      0.8113
#   science      0.8120
# ------------------------------------------------------------
# Words: ['mystery', 'thriller', 'crime', 'austen']
# Expected odd word: austen
# Model output: austen
# Correct: True
# Scores, lower means more likely to be odd:
#   austen       0.3413
#   crime        0.5606
#   thriller     0.6842
#   mystery      0.6876
# ------------------------------------------------------------
# Words: ['fiction', 'novel', 'story', 'business']
# Expected odd word: business
# Model output: story
# Correct: False
# Scores, lower means more likely to be odd:
#   story        0.5168
#   business     0.7786
#   fiction      0.7862
#   novel        0.8303
# ------------------------------------------------------------
# Words: ['fantasy', 'magic', 'fiction', 'biography']
# Expected odd word: biography
# Model output: magic
# Correct: False
# Scores, lower means more likely to be odd:
#   magic        0.5438
#   biography    0.7974
#   fiction      0.8005
#   fantasy      0.8404
# ------------------------------------------------------------
# Words: ['mystery', 'thriller', 'crime', 'poetry']
# Expected odd word: poetry
# Model output: crime
# Correct: False
# Scores, lower means more likely to be odd:
#   crime        0.6728
#   poetry       0.8535
#   thriller     0.8827
#   mystery      0.8890
# ------------------------------------------------------------
# Words: ['history', 'historical', 'century', 'romance']
# Expected odd word: romance
# Model output: century
# Correct: False
# Scores, lower means more likely to be odd:
#   century      0.6181
#   history      0.8437
#   romance      0.8534
#   historical   0.8705
# ------------------------------------------------------------
# Words: ['biography', 'memoir', 'life', 'horror']
# Expected odd word: horror
# Model output: life
# Correct: False
# Scores, lower means more likely to be odd:
#   life         0.3839
#   memoir       0.7802
#   biography    0.7810
#   horror       0.7838
# ------------------------------------------------------------
# Words: ['child', 'young', 'adult', 'business']
# Expected odd word: business
# Model output: adult
# Correct: False
# Scores, lower means more likely to be odd:
#   adult        0.9256
#   young        0.9338
#   business     0.9405
#   child        0.9426
# ------------------------------------------------------------
# Words: ['austen', 'fitzgerald', 'miller', 'travel']
# Expected odd word: travel
# Model output: travel
# Correct: True
# Scores, lower means more likely to be odd:
#   travel       0.3198
#   miller       0.3998
#   fitzgerald   0.4058
#   austen       0.4293
# ------------------------------------------------------------
# Words: ['romance', 'love', 'family', 'science']
# Expected odd word: science
# Model output: family
# Correct: False
# Scores, lower means more likely to be odd:
#   family       0.4461
#   love         0.4654
#   science      0.5555
#   romance      0.5798
# ------------------------------------------------------------
# Words: ['music', 'art', 'poetry', 'thriller']
# Expected odd word: thriller
# Model output: thriller
# Correct: True
# Scores, lower means more likely to be odd:
#   thriller     0.9542
#   art          0.9582
#   music        0.9752
#   poetry       0.9769
# ------------------------------------------------------------
# Words: ['business', 'psychology', 'self', 'fantasy']
# Expected odd word: fantasy
# Model output: fantasy
# Correct: True
# Scores, lower means more likely to be odd:
#   fantasy      0.9560
#   business     0.9658
#   self         0.9686
#   psychology   0.9738
# ------------------------------------------------------------
# Final score: 13/20
# Warning: 'nietzsch' was not found in the vocabulary.
# Warning: 'camu' was not found in the vocabulary.

# %% [markdown]
# ## 11. Optional: Save and Reload the Scratch Model
#
# Saving a trained model is useful when training takes a long time and we want to reuse the model later.
#
# This section demonstrates saving and reloading the scratch Word2Vec model.

# %%
scratch_model_path = Path("scratch_word2vec_answer.model")

scratch_model.save(
    path=scratch_model_path,
    word2idx=scratch_dataset.word2idx,
    idx2word=scratch_dataset.idx2word,
)

reloaded_scratch_model = ScratchWord2Vec.load(scratch_model_path)

print(f"Scratch model saved and reloaded from: {scratch_model_path}")
print(f"Reloaded embedding shape: {reloaded_scratch_model.W_in.shape}")
# Out:
# Scratch model saved and reloaded from: scratch_word2vec_answer.model
# Reloaded embedding shape: (22521, 100)

# %% [markdown]
# ## 12. Model Comparison
#
# explain each model and compare their results
#
#
# ##TODO

# %% [markdown]
# . Scratch Word2Vec (Skip-Gram with Negative Sampling)
#
# Built entirely with NumPy — no library does the heavy lifting. For each word in a sentence, it predicts nearby context words within a window, using one trainable input vector and one output vector per word. Negative sampling avoids computing a full softmax over the vocabulary by contrasting each true context word against a handful of random "negative" words. This is the slowest and most resource-intensive option since training is a manual Python loop over every (center, context) pair, with no vectorized batch updates.
# 2. Gensim FastText
#
# Uses the well-optimized, production-grade Gensim library, which implements the same skip-gram idea as Word2Vec but adds subword (character n-gram) information — so it can represent words it has never seen by composing them from known character chunks. Training is in compiled Cython under the hood, making it dramatically faster than the scratch version for the same data.
# 3. Native FastText (Facebook's fasttext package)
#
# The original C++ implementation from Facebook Research, wrapped in Python. It's typically the fastest of the three because it's compiled native code with multi-threading support, and like Gensim FastText, benefits from subword embeddings.
#
#
# Expected pattern (typical for this kind of small-corpus comparison, to be confirmed by your actual run):
#
# Scratch Word2Vec usually scores reasonably on odd-one-out for common/frequent words, but is by far the slowest to train and has zero ability to handle words outside its fixed vocabulary.
# Gensim FastText usually gets the best odd-one-out accuracy for the time invested — subword information helps it generalize better on a modest-sized book-description corpus where many words are rare.
# Native FastText is typically the fastest in wall-clock time, with accuracy comparable to or slightly below Gensim FastText (architecture is similar; differences come down to implementation details and default hyperparameters).
